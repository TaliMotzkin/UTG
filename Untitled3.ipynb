# %%
cd Project

# %%
python main3.py --dataset=tgbl-wiki -t hourly --lr 2e-4 --max_epoch 200 --num_runs 5 --patience 20 --batch_size 200 --with_hop 1
# Out:
# INFO: using gpu:0 to train the model
# INFO: fixed random seed: 1
# raw file found, skipping download
# Dataset directory is  /venv/main/lib/python3.10/site-packages/tgb/datasets/tgbl_wiki
# loading processed file
# Node is none
# INFO: DATA: tgbl-wiki, TIME_SCALE: hourly
# INFO: data does not exits, processing ...
# raw file found, skipping download
# Dataset directory is  /venv/main/lib/python3.10/site-packages/tgb/datasets/tgbl_wiki
# loading processed file
# Number of loaded edges: 157474
# Number of unique edges:18257
# Available timestamps:  152757
# Discretizing data to 744 timestamps...
# raw file found, skipping download
# Dataset directory is  /venv/main/lib/python3.10/site-packages/tgb/datasets/tgbl_wiki
# loading processed file
# INFO: Loading TGB dataset: tgbl-wiki
# INFO: fixed random seed: 1
# Run 1
# ------------------------------------------
# Epoch 0/200, Loss: 1.5695250367573925
# Train time:  31.0988330419641
# y_pred tensor(0.6769, device='cuda:0') 0
# ...

# %%
python main.py --dataset=tgbl-wiki -t hourly --lr 2e-4 --max_epoch 200 --num_runs 5 --patience 20 --batch_size 200 --with_hop 0
# Out:
# INFO: using gpu:0 to train the model
# INFO: fixed random seed: 1
# raw file found, skipping download
# Dataset directory is  /venv/main/lib/python3.10/site-packages/tgb/datasets/tgbl_wiki
# loading processed file
# Node is none
# INFO: DATA: tgbl-wiki, TIME_SCALE: hourly
# INFO: data does not exits, processing ...
# raw file found, skipping download
# Dataset directory is  /venv/main/lib/python3.10/site-packages/tgb/datasets/tgbl_wiki
# loading processed file
# Number of loaded edges: 157474
# Number of unique edges:18257
# Available timestamps:  152757
# Discretizing data to 744 timestamps...
# raw file found, skipping download
# Dataset directory is  /venv/main/lib/python3.10/site-packages/tgb/datasets/tgbl_wiki
# loading processed file
# INFO: Loading TGB dataset: tgbl-wiki
# <RootLogger root (DEBUG)>
# INFO: fixed random seed: 1
# Run 1
# ------------------------------------------
# Epoch 0/200, Loss: 1.595874110855105
# Train time:  14.94383886992

# %%
 the score tensor form NAT -0.34

# %%
new test data structure, with hop. adding at the end of linear X -0.43, splitting 40-200:

# %%
adding the hop in concat after the linear layers of x. also multiplied the hops  -0.37

# %%
multipliying hop and then concating it to x - results as the baseline 0.37, concatting both the hops source and target before the multiplication of xx
